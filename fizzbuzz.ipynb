# %%
for i in range (1,101):

    if i % 3 == 0:
        if (i % 2 == 0) & (i % 3 == 0) & (i % 5 == 0):
            print('hottfizzbuzz')

        elif (i % 2 == 0) & (i % 3== 0):
            print('hottfizz')

        elif (i % 2 == 0) & (i % 5 == 0):
            print('hottbuzz')

        else:print('fizz')



    elif i % 2 == 0:
        print("hott")
    elif i % 5 == 0:
        print("Buzz")

    else:
        print(i)
# Out:
# 1
# hott
# fizz
# hott
# Buzz
# hottfizz
# 7
# hott
# fizz
# hott
# 11
# hottfizz
# 13
# hott
# fizz
# hott
# 17
# hottfizz
# 19
# hott
# fizz
# hott
# 23
# hottfizz
# Buzz
# hott
# fizz
# hott
# 29
# hottfizzbuzz
# 31
# hott
# fizz
# hott
# Buzz
# hottfizz
# 37
# hott
# fizz
# hott
# 41
# hottfizz
# 43
# hott
# fizz
# hott
# 47
# hottfizz
# 49
# hott
# fizz
# hott
# 53
# hottfizz
# Buzz
# hott
# fizz
# hott
# 59
# hottfizzbuzz
# 61
# hott
# fizz
# hott
# Buzz
# hottfizz
# 67
# hott
# fizz
# hott
# 71
# hottfizz
# 73
# hott
# fizz
# hott
# 77
# hottfizz
# 79
# hott
# fizz
# hott
# 83
# hottfizz
# Buzz
# hott
# fizz
# hott
# 89
# hottfizzbuzz
# 91
# hott
# fizz
# hott
# Buzz
# hottfizz
# 97
# hott
# fizz
# hott
