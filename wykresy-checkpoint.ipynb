# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
plt.plot(np.random.rand(10))

# %%
plt.style.use('ggplot')

# %%
plt.plot(np.random.rand(10))
plt.plot(np.random.rand(10))

# %%
for i in range (4):
    plt.plot(np.random.rand(10))

# %%
for i in range (400):
    plt.plot(np.random.rand(10))

# %%
x = np.linspace(0,10,100)

fig  = plt.figure()


plt.plot(x, np.sin(x), '-')
plt.plot(x, np.cos(x), '--')

# %%
fig.savefig('my_figure.png') #zapisanie obrazu

# %%
plt.figure()

plt.subplot(2,1,1) #wiersze koluny który wykres
plt.plot(x, np.sin(x), '-')
         
plt.subplot(2,1,2)
plt.plot(x, np.cos(x), '--')

# %%
fig, ax = plt.subplots(2)

ax[0].polt(x, np.sin(x))
ax[1].polt(x, np.cos(x))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14800/344681996.py in <module>
#       1 fig, ax = plt.subplots(2)
#       2
# ----> 3 ax[0].polt(x, np.sin(x))
#       4 ax[1].polt(x, np.cos(x))
#
# AttributeError: 'AxesSubplot' object has no attribute 'polt'

# %%
fig = plt.figure()
ax = plt.axes()

x=np.linspace(0,10,1000)
ax.plot(x, np.sin(x));

# %%
colors = [
    'blue',          #kolory
    'g',
    '0.75',
    '#FFDD44',
    (1.0,0.2,0.3)
    
    
    
    
]

for i, color in enumerate(colors):
    plt.plot(x, np.sin(x-1), color=color)

# %%
#zkres osi

plt.plot(x, np.sin(x))

plt.xlim(-1,11)
plt.ylim(-2,2)
# Out:
# (-2.0, 2.0)

# %%
# dodawanie ozanczeni

plt.plot(x, np.sin(x))
plt.title('sadsa')
plt.xlabel('x')
plt.ylabel('sinx')
# Out:
# Text(0, 0.5, 'sinx')

# %%
# w pytonie

ax = plt.axes()
ax.plot(x, np.sin(x))
ax.set(xlim=(0,10),ylim=(0,10))
# Out:
# [(0.0, 10.0), (0.0, 10.0)]

# %%
plt.plot(x, y ,'-p', color='gray',
        markersize=15, linewidth=4,
        markerfacecolor='withe');
# Out:
# ----------------------------------------------------------------
# NameError                      Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14800/1802883234.py in <module>
# ----> 1 plt.plot(x, y ,'-p', color='gray',
#       2         markersize=15, linewidth=4,
#       3         markerfacecolor='withe');
#
# NameError: name 'y' is not defined

# %%
plt.scater(

    np.random.randn(100)
    np.random.randn(100)
    c=np.random.rand(100)
    s=np.random.rand(100)

)
# Out:
#   File "C:\Users\mrgrz\AppData\Local\Temp/ipykernel_14800/3891856943.py", line 4
#     np.random.randn(100)
#     ^
# SyntaxError: invalid syntax
