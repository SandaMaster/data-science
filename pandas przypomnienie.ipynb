# %%
import numpy
import pandas as pd

# %%
path = pd.read_csv('winemag-data-130k-v2', sep=',')

a= pd.DataFrame({
    'Yes':[123,124],
    'No':[546,789]
})
print(a)

b= pd.DataFrame({
    'Bob':['lubie', 'nie lubie'],
    'sue':['ladny','brzydki']

},index = ['word A', 'word B'])


pd.Series([2,3,4,5])
# Out:
#    Yes   No
# 0  123  546
# 1  124  789
# 0    2
# 1    3
# 2    4
# 3    5
# dtype: int64

# %%
a
# Out:
#    Yes   No
# 0  123  546
# 1  124  789

# %%
b
# Out:
#               Bob      sue
# word A      lubie    ladny
# word B  nie lubie  brzydki

# %%
path = pd.read_csv('winemag-data-130k-v2.csv', sep=',')
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...

# %%
path.head() # pierwsze 5 kolumn
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
path = pd.read_csv('winemag-data-130k-v2.csv', index_col=0)

# %%
path
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# ...

# %%
path['country']
# Out:
# 0            Italy
# 1         Portugal
# 2               US
# 3               US
# 4               US
#             ...
# 129966     Germany
# 129967          US
# 129968      France
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
path.country
# Out:
# 0            Italy
# 1         Portugal
# 2               US
# 3               US
# 4               US
#             ...
# 129966     Germany
# 129967          US
# 129968      France
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
path.country[12966] # indeskowanie series
# Out:
# 'US'

# %%
path.iloc[1,2] # indeksy od 0 jak w pyhonie
# Out:
# 'Avidagos'

# %%
path.loc[1,'designation'] # indeksy pandasowe, nazwa kolomy
# Out:
# 'Avidagos'

# %%
path.loc[:3, 'points'] # puerwsze 4 wiersze, slices
# Out:
# 0    87
# 1    87
# 2    87
# 3    87
# Name: points, dtype: int64

# %%
path.iloc[:3, 3] # róznica
# Out:
# 0    87
# 1    87
# 2    87
# Name: points, dtype: int64

# %%
### Filtrowanaie

# %%
path.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
# jak otrzyamc wina które pochodz z wloch

# %%
path.country == 'Italy'
# Out:
# 0          True
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 129966    False
# 129967    False
# 129968    False
# 129969    False
# 129970    False
# Name: country, Length: 129971, dtype: bool

# %%
path[path.country == 'Italy'] # tylko dla ktorych istnieje
# Out:
#        country                                        description  \
# 0        Italy  Aromas include tropical fruit, broom, brimston...
# 6        Italy  Here's a bright, informal red that opens with ...
# 13       Italy  This is dominated by oak and oak-driven aromas...
# 22       Italy  Delicate aromas recall white flower and citrus...
# 24       Italy  Aromas of prune, blackcurrant, toast and oak c...
# ...        ...                                                ...
# 129929   Italy  This luminous sparkler has a sweet, fruit-forw...
# 129943   Italy  A blend of Nero d'Avola and Syrah, this convey...
# 129947   Italy  A blend of 65% Cabernet Sauvignon, 30% Merlot ...
# 129961   Italy  Intense aromas of wild cherry, baking spice, t...
# 129962   Italy  Blackberry, cassis, grilled herb and toasted a...
#
#                       designation  points  price           province  \
# 0                    Vulkà Bianco      87    NaN  Sicily & Sardinia
# ...

# %%
[(path.country == 'Italy') | (path.country == 'Germany')] # warunek alternatywy
# Out:
# [0          True
#  1         False
#  2         False
#  3         False
#  4         False
#            ...
#  129966     True
#  129967    False
#  129968    False
#  129969    False
#  129970    False
#  Name: country, Length: 129971, dtype: bool]

# %%
path[(path.country == 'Italy') | (path.country == 'Germany')]
# Out:
#         country                                        description  \
# 0         Italy  Aromas include tropical fruit, broom, brimston...
# 6         Italy  Here's a bright, informal red that opens with ...
# 8       Germany  Savory dried thyme notes accent sunnier flavor...
# 13        Italy  This is dominated by oak and oak-driven aromas...
# 15      Germany  Zesty orange peels and apple notes abound in t...
# ...         ...                                                ...
# 129946  Germany  Plump, clingy peach and honey notes are cut wi...
# 129947    Italy  A blend of 65% Cabernet Sauvignon, 30% Merlot ...
# 129961    Italy  Intense aromas of wild cherry, baking spice, t...
# 129962    Italy  Blackberry, cassis, grilled herb and toasted a...
# 129966  Germany  Notes of honeysuckle and cantaloupe sweeten th...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# ...

# %%
path[(path.country == 'Italy') & (path.points >= 90)] # wicje niz 90 pkt
# Out:
#        country                                        description  \
# 120      Italy  Slightly backward, particularly given the vint...
# 130      Italy  At the first it was quite muted and subdued, b...
# 133      Italy  Einaudi's wines have been improving lately, an...
# 135      Italy  The color is just beginning to show signs of b...
# 140      Italy  A big, fat, luscious wine with plenty of toast...
# ...        ...                                                ...
# 129929   Italy  This luminous sparkler has a sweet, fruit-forw...
# 129943   Italy  A blend of Nero d'Avola and Syrah, this convey...
# 129947   Italy  A blend of 65% Cabernet Sauvignon, 30% Merlot ...
# 129961   Italy  Intense aromas of wild cherry, baking spice, t...
# 129962   Italy  Blackberry, cassis, grilled herb and toasted a...
#
#                       designation  points  price           province  \
# 120           Bricco Rocche Prapó      92   70.0           Piedmont
# ...

# %%
path.country.isin(['Italy', 'France']) #metoda isin
# Out:
# 0          True
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 129966    False
# 129967    False
# 129968     True
# 129969     True
# 129970     True
# Name: country, Length: 129971, dtype: bool

# %%
path[path.country.isin(['Italy', 'France','Germany'])]
# Out:
#         country                                        description  \
# 0         Italy  Aromas include tropical fruit, broom, brimston...
# 6         Italy  Here's a bright, informal red that opens with ...
# 7        France  This dry and restrained wine offers spice in p...
# 8       Germany  Savory dried thyme notes accent sunnier flavor...
# 9        France  This has great depth of flavor with its fresh ...
# ...         ...                                                ...
# 129965   France  While it's rich, this beautiful dry wine also ...
# 129966  Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129968   France  Well-drained gravel soil gives this wine its c...
# 129969   France  A dry style of Pinot Gris, this is crisp with ...
# 129970   France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# ...

# %%
path[path.country.isin(['Italy', 'France', 'Germany']) &
           path.points.between(90, 95)]
# Out:
#         country                                        description  \
# 119      France  Medium-gold in color. Complex and inviting nos...
# 120       Italy  Slightly backward, particularly given the vint...
# 126      France  Mid-gold color. Pronounced and enticing aromas...
# 127      France  Attractive mid-gold color with intense aromas ...
# 128      France  Compelling minerality on the nose, Refined and...
# ...         ...                                                ...
# 129965   France  While it's rich, this beautiful dry wine also ...
# 129966  Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129968   France  Well-drained gravel soil gives this wine its c...
# 129969   France  A dry style of Pinot Gris, this is crisp with ...
# 129970   France  Big, rich and off-dry, this is powered by inte...
#
#                                        designation  points  price  province  \
# 119     Schoenenbourg Grand Cru Vendanges Tardives      92   80.0    Alsace
# ...

# %%
path[path.price.notnull()]
# Out:
#          country                                        description  \
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# 5          Spain  Blackberry and raspberry aromas show a typical...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price        province  \
# ...

# %%
path['critic'] = 'everyone' #tworzenie nowych kolum z wartosciami

# %%
path
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# ...

# %%
path[list(path.columns[:8]) + ['critic'] + list(path.columns[8:-1])]
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# ...

# %%
path.insert(6, 'critic', path.pop('critic'))

# %%
path
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# ...

# %%
## funkcje mapy

# %%
# funkcje podsumowyjce

# %%
path.describe() # wartosci liczbowe śr. odchylenie itp
# Out:
#               points          price
# count  129971.000000  120975.000000
# mean       88.447138      35.363389
# std         3.039730      41.022218
# min        80.000000       4.000000
# 25%        86.000000      17.000000
# 50%        88.000000      25.000000
# 75%        91.000000      42.000000
# max       100.000000    3300.000000

# %%
path.taster_name.describe() # z konkretnej kolumy
# Out:
# count         103727
# unique            19
# top       Roger Voss
# freq           25514
# Name: taster_name, dtype: object

# %%
path.points.mean() #srednia
# Out:
# 88.44713820775404

# %%
path.taster_name.value_counts() # iel razy ystepuej w data frame
# Out:
# Roger Voss            25514
# Michael Schachner     15134
# Kerin O’Keefe         10776
# Virginie Boone         9537
# Paul Gregutt           9532
# Matt Kettmann          6332
# Joe Czerwinski         5147
# Sean P. Sullivan       4966
# Anna Lee C. Iijima     4415
# Jim Gordon             4177
# Anne Krebiehl MW       3685
# Lauren Buzzeo          1835
# Susan Kostrzewa        1085
# Mike DeSimone           514
# Jeff Jenssen            491
# Alexander Peartree      415
# Carrie Dykes            139
# Fiona Adams              27
# Christina Pickard         6
# Name: taster_name, dtype: int64

# %%
## mapy

# %%
l  =[1,2,3]
def mul2(x):
    return l*2

# %%
list(map(mul2, l))
# Out:
# [[1, 2, 3, 1, 2, 3], [1, 2, 3, 1, 2, 3], [1, 2, 3, 1, 2, 3]]

# %%
mean_ponist = path.points.mean()
def remean(points):
    return points - mean_ponist
path.pointspath.points.map(remean) # odejmuje od kazdengo wina srednia
# Out:
# (0         87
#  1         87
#  2         87
#  3         87
#  4         87
#            ..
#  129966    90
#  129967    90
#  129968    90
#  129969    90
#  129970    90
#  Name: points, Length: 129971, dtype: int64,
#  0        -1.447138
#  1        -1.447138
#  2        -1.447138
#  3        -1.447138
#  4        -1.447138
#              ...
#  129966    1.552862
#  129967    1.552862
#  129968    1.552862
#  129969    1.552862
#  129970    1.552862
#  Name: points, Length: 129971, dtype: float64)

# %%
path.points.map(lambda points: points - mean_ponist) # to samo tylko z lambda
# dobre jek jest mało skomplikowana funkcja xD
# Out:
# 0        -1.447138
# 1        -1.447138
# 2        -1.447138
# 3        -1.447138
# 4        -1.447138
#             ...
# 129966    1.552862
# 129967    1.552862
# 129968    1.552862
# 129969    1.552862
# 129970    1.552862
# Name: points, Length: 129971, dtype: float64

# %%
# apply

# %%
def reman(row):
    row.points = raw.points - mean_ponist
    return raw

path.apply(mean_ponist, axis='columns')



# def remean_points(row):
#     row.points = row.points - review_points_mean
#     return row

# reviews_df.apply(remean_points, axis='columns')
# Out:
# --------------------------------------------------------------
# TypeError                    Traceback (most recent call last)
# <ipython-input-130-520534281d40> in <module>
#       3     return raw
#       4
# ----> 5 path.apply(mean_ponist, axis='columns')
#       6
#       7
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7766             kwds=kwds,
#    7767         )
# -> 7768         return op.get_result()
#    7769
#    7770     def applymap(self, func, na_action: Optional[str] = None) -> DataFrame:
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in get_result(self)
#     183             return self.apply_raw()
#     184
# --> 185         return self.apply_standard()
#     186
#     187     def apply_empty_result(self):
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     274
#     275     def apply_standard(self):
# ...

# %%
path.country + '-' + path.region_1
# Out:
# 0                     Italy-Etna
# 1                            NaN
# 2           US-Willamette Valley
# 3         US-Lake Michigan Shore
# 4           US-Willamette Valley
#                    ...
# 129966                       NaN
# 129967                 US-Oregon
# 129968             France-Alsace
# 129969             France-Alsace
# 129970             France-Alsace
# Length: 129971, dtype: object

# %%
path.points - mean_ponist
# Out:
# 0        -1.447138
# 1        -1.447138
# 2        -1.447138
# 3        -1.447138
# 4        -1.447138
#             ...
# 129966    1.552862
# 129967    1.552862
# 129968    1.552862
# 129969    1.552862
# 129970    1.552862
# Name: points, Length: 129971, dtype: float64

# %%
# grupowanie sortowanie

# %%
path.groupby('points').points.count()  #dzielimy na podstawie kolumny dal jednej wartosci
# Out:
# points
# 80       397
# 81       692
# 82      1836
# 83      3025
# 84      6480
# 85      9530
# 86     12600
# 87     16933
# 88     17207
# 89     12226
# 90     15410
# 91     11359
# 92      9613
# 93      6489
# 94      3758
# 95      1535
# 96       523
# 97       229
# 98        77
# 99        33
# 100       19
# Name: points, dtype: int64

# %%
path.points.value_counts() # to samo co gropu by
# Out:
# 88     17207
# 87     16933
# 90     15410
# 86     12600
# 89     12226
# 91     11359
# 92      9613
# 85      9530
# 93      6489
# 84      6480
# 94      3758
# 83      3025
# 82      1836
# 95      1535
# 81       692
# 96       523
# 80       397
# 97       229
# 98        77
# 99        33
# 100       19
# Name: points, dtype: int64

# %%
path.groupby('points').points.min()
# Out:
# points
# 80      80
# 81      81
# 82      82
# 83      83
# 84      84
# 85      85
# 86      86
# 87      87
# 88      88
# 89      89
# 90      90
# 91      91
# 92      92
# 93      93
# 94      94
# 95      95
# 96      96
# 97      97
# 98      98
# 99      99
# 100    100
# Name: points, dtype: int64

# %%
path.groupby('points').price.mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='points'>

# %%
path.sort_values('price', ascending=False) # sortowanie po wartościach
# Out:
#          country                                        description  \
# 80290     France  This ripe wine shows plenty of blackberry frui...
# 15840     France  The wine is a velvet glove in an iron fist. Th...
# 98380     France  A superb wine from a great year, this is power...
# 120391        US  The nose on this single-vineyard wine from a s...
# 113564    France  A wonderfully complete wine, with all the elem...
# ...          ...                                                ...
# 129844     Italy  Doga delle Clavule is a neutral, mineral-drive...
# 129860  Portugal  This rich wine has a firm structure as well as...
# 129863  Portugal  This mature wine that has 50% Touriga Nacional...
# 129893     Italy  Aromas of passion fruit, hay and a vegetal not...
# 129964    France  Initially quite muted, this wine slowly develo...
#
#                          designation  points   price    province    critic  \
# ...

# %%
# zmienianie nazwy kolum

# %%
path['score']  = path['points']

# %%
del path['score']

# %%
path[path['country'] == 'Italy']
# Out:
#        country                                        description  \
# 0        Italy  Aromas include tropical fruit, broom, brimston...
# 6        Italy  Here's a bright, informal red that opens with ...
# 13       Italy  This is dominated by oak and oak-driven aromas...
# 22       Italy  Delicate aromas recall white flower and citrus...
# 24       Italy  Aromas of prune, blackcurrant, toast and oak c...
# ...        ...                                                ...
# 129929   Italy  This luminous sparkler has a sweet, fruit-forw...
# 129943   Italy  A blend of Nero d'Avola and Syrah, this convey...
# 129947   Italy  A blend of 65% Cabernet Sauvignon, 30% Merlot ...
# 129961   Italy  Intense aromas of wild cherry, baking spice, t...
# 129962   Italy  Blackberry, cassis, grilled herb and toasted a...
#
#                       designation  points  price           province    critic  \
# 0                    Vulkà Bianco      87    NaN  Sicily & Sardinia  everyone
# ...

# %%
path.rename(columns = {'points':'score'}) # szybkie zamienian nazw kolumn
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  score  price  \
# 0                                 Vulkà Bianco     87    NaN
# ...

# %%
#joiny

# %%
path.groupby('country').price.mean()
# Out:
# country
# Argentina                 24.510117
# Armenia                   14.500000
# Australia                 35.437663
# Austria                   30.762772
# Bosnia and Herzegovina    12.500000
# Brazil                    23.765957
# Bulgaria                  14.645390
# Canada                    35.712598
# Chile                     20.786458
# China                     18.000000
# Croatia                   25.450704
# Cyprus                    16.272727
# Czech Republic            24.250000
# Egypt                           NaN
# England                   51.681159
# France                    41.139120
# Georgia                   19.321429
# Germany                   42.257547
# Greece                    22.364425
# Hungary                   40.648276
# India                     13.333333
# Israel                    31.768916
# Italy                     39.663770
# Lebanon                   30.685714
# Luxembourg                23.333333
# Macedonia                 15.583333
# ...

# %%
nwe_colum =path.groupby('country', as_index=False).price.mean()

# %%
nwe_colum = nwe_colum.rename(columns={'price':'mean_price1'})

# %%
path.merge(nwe_colum)# dodawanie nowych kolum
# Out:
#           country                                        description  \
# 0           Italy  Aromas include tropical fruit, broom, brimston...
# 1           Italy  Here's a bright, informal red that opens with ...
# 2           Italy  This is dominated by oak and oak-driven aromas...
# 3           Italy  Delicate aromas recall white flower and citrus...
# 4           Italy  Aromas of prune, blackcurrant, toast and oak c...
# ...           ...                                                ...
# 129903  Macedonia  Lavender and ripe black-cherry aromas are enti...
# 129904  Macedonia  This Merlot-Cabernet-Vranec blend offers an ap...
# 129905  Macedonia  This garnet-colored Pinot Noir is named after ...
# 129906      China  This deep ruby-colored wine features a bouquet...
# 129907      Egypt  Ripe pear, apple and tropical fruit in the nos...
#
#                   designation  points  price           province   critic  \
# ...

# %%
path['remean_price'] = path['price'] - path['mean_price1']
# Out:
# --------------------------------------------------------------
# KeyError                     Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'mean_price1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                     Traceback (most recent call last)
# <ipython-input-161-a1bdc7784992> in <module>
# ----> 1 path['remean_price'] = path['price'] - path['mean_price1']
#
# ...
